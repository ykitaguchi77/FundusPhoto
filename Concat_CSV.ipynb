# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/FundusPhoto/blob/main/Concat_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Concat CSV file**

# %%
import pandas as pd

#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**Concat_frames**

# %%
#画像番号と年齢のみを抜き出し
df = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_5_CLAHE.csv", index_col=0, sep=",")
df = df.iloc[:, 0:1]
df
# Out:
#                    age
# Unnamed: 1
# img76901008_06_1R   70
# img76901008_06_2L   68
# img76901008_07_1R   69
# img76901008_07_2L   66
# img77009741_01_1R   44
# ...                ...
# img99962800_00_1L   29
# img99962810_00_1R   30
# img99962820_00_1R   30
# img99962830_00_1R   29
# img99962840_00_1R   30
#
# [401 rows x 1 columns]

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_5_GB.csv", index_col=0, sep=",")
#df1

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_5_CLAHE.csv", index_col=0, sep=",")
#df2

# %%
df3 = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_6.csv", index_col=0, sep=",")
#df3

# %%
df4 = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_7.csv", index_col=0, sep=",")
#df4

# %%
#0列目がageに相当
df1= df1.iloc[:,1:36]
#print(df1.columns)

# %%
#0列目がageに相当
df2= df2.iloc[:,1:41]
#print(df2.columns)

# %%
#0列目がageに相当
df3= df2.iloc[:,1:41]
#print(df3.columns)

# %%
#0列目がageに相当
df4= df4.iloc[:,1:41]
#print(df4.columns)

# %%
df_dst = pd.concat([df, df1, df2, df3, df4],axis=1)

# %%
print(df_dst)
print(len(df_dst.columns))
# Out:
#                    age  ...  vascular_2_RGB_B3_GB_L1Loss_pretrained_4
# Unnamed: 1              ...
# img76901008_06_1R   70  ...                                 53.131670
# img76901008_06_2L   68  ...                                 55.750787
# img76901008_07_1R   69  ...                                 52.608454
# img76901008_07_2L   66  ...                                 54.159564
# img77009741_01_1R   44  ...                                 50.823110
# ...                ...  ...                                       ...
# img99962800_00_1L   29  ...                                 52.267468
# img99962810_00_1R   30  ...                                 51.456147
# img99962820_00_1R   30  ...                                 52.083141
# img99962830_00_1R   29  ...                                 51.914799
# img99962840_00_1R   30  ...                                 51.695716
#
# [401 rows x 155 columns]
# 155

# %%
df_dst.to_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_concat.csv", encoding='utf_8_sig')

# %% [markdown]
# #**Delete columns from Dataframe**

# %%
#画像番号と年齢のみを抜き出し
df = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/result_5_CLAHE.csv", index_col=0, sep=",")
df

# %%
df_counterpart = pd.read_csv("/content/drive/MyDrive/Deep_learning/FundusPhoto/【眼科AIコンテスト】本番用データ提出フォーム_result_5_CLAHE.csv", index_col=0, sep=",")
df_counterpart
# Out:
#                    age  ...  vascular_CLAHE_B3_ver2_pretrained_4
# Unnamed: 1              ...
# img76901008_06_1R   70  ...                            59.878999
# img76901008_06_2L   68  ...                            48.995674
# img76901008_07_1R   69  ...                            54.314357
# img76901008_07_2L   66  ...                            49.047279
# img77009741_01_1R   44  ...                            41.672936
# ...                ...  ...                                  ...
# img99962800_00_1L   29  ...                            44.824556
# img99962810_00_1R   30  ...                            51.548409
# img99962820_00_1R   30  ...                            43.355364
# img99962830_00_1R   29  ...                            42.282969
# img99962840_00_1R   30  ...                            59.662741
#
# [401 rows x 41 columns]
